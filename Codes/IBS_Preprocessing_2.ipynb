# %%
import pandas as pd

# %%
df_alpha = pd.read_csv("./Datasets/AlphaSP_Fragmented.csv")
df_alpha = df_alpha.iloc[:,1:] 
df_alpha.columns = ["ACC","Seq"]
df_alpha["Var"]="alpha" 
df_alpha
# Out:
#            ACC                                                Seq    Var
# 0   UCI81335.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 1   UCI83278.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 2   QWO21500.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 3   QWO21512.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 4   QUR41478.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 5   QUR41490.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 6   QUR41502.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 7   QUR41514.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 8   QUI75445.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 9   QUI75457.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 10  QUI75469.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# 11  QUB25743.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  alpha
# ...

# %%
df_beta = pd.read_csv("./Datasets/BetaSP_Fragmented.csv")
df_beta = df_beta.iloc[:,1:] 
df_beta.columns = ["ACC","Seq"]
df_beta["Var"]="beta" 
df_beta
# Out:
#             ACC                                                Seq   Var
# 0    UQA03890.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
# 1    UQA04604.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
# 2    UQA06054.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
# 3    UQA06270.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
# 4    UQC44117.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
# ..          ...                                                ...   ...
# 195  UNW47845.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
# 196  UNW47857.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
# 197  UNW47869.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
# 198  UNW47881.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  beta
# 199  UNW47893.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  beta
#
# [200 rows x 3 columns]

# %%
df_delta = pd.read_csv("./Datasets/DeltaSP_Fragmented.csv")
df_delta = df_delta.iloc[:,1:] 
df_delta.columns = ["ACC","Seq"]
df_delta["Var"]="delta" 
df_delta
# Out:
#             ACC                                                Seq    Var
# 0    UQH71295.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  delta
# 1    UQH72965.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  delta
# 2    UQG73840.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  delta
# 3    UQG73958.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  delta
# 4    UQG74252.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  delta
# ..          ...                                                ...    ...
# 195  UPZ72424.1  KVFRS VFRSS FRSSV RSSVL SSVLH SVLHS VLHST LHST...  delta
# 196  UPZ72436.1  KVFRS VFRSS FRSSV RSSVL SSVLH SVLHS VLHST LHST...  delta
# 197  UPZ72556.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  delta
# 198  UPZ74093.1  KVFRS VFRSS FRSSV RSSVL SSVLH SVLHS VLHST LHST...  delta
# 199  UPZ75133.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  delta
#
# [200 rows x 3 columns]

# %%
df_gamma = pd.read_csv("./Datasets/GammaSP_Fragmented.csv")
df_gamma = df_gamma.iloc[:,1:] 
df_gamma.columns = ["ACC","Seq"]
df_gamma["Var"]="gamma" 
df_gamma
# Out:
#             ACC                                                Seq    Var
# 0    UQG74240.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
# 1    UQG74416.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
# 2    UQG74428.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
# 3    UQG74807.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
# 4    UQG75292.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
# ..          ...                                                ...    ...
# 195  UNY78429.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
# 196  UNY79298.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
# 197  UNU86617.1  SQCVN QCVNF CVNFT VNFTN NFTNR FTNRT TNRTQ NRTQ...  gamma
# 198  UNV29893.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
# 199  UNL47546.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  gamma
#
# [200 rows x 3 columns]

# %%
df_eta = pd.read_csv("./Datasets/EtaSP_Fragmented.csv")
df_eta = df_eta.iloc[:,1:] 
df_eta.columns = ["ACC","Seq"]
df_eta["Var"]="eta" 
df_eta
# Out:
#             ACC                                                Seq  Var
# 0    UQC58502.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# 1    UQC58833.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# 2    UQC59125.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# 3    UQC59336.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# 4    UPD40192.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# ..          ...                                                ...  ...
# 195  UFI40999.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# 196  UFI41011.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# 197  UFI41023.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# 198  UFI41035.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
# 199  UFI41047.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  eta
#
# [200 rows x 3 columns]

# %%
df_iota = pd.read_csv("./Datasets/IotaSP_Fragmented.csv")
df_iota = df_iota.iloc[:,1:] 
df_iota.columns = ["ACC","Seq"]
df_iota["Var"]="iota" 
df_iota
# Out:
#             ACC                                                Seq   Var
# 0    UQG74499.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  iota
# 1    UPW88534.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  iota
# 2    UPW88546.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  iota
# 3    UPW88569.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  iota
# 4    UPW88604.1  SQCVN QCVNL CVNLT VNLTT NLTTT LTTTT TTTTQ TTTQ...  iota
# ..          ...                                                ...   ...
# 195  UKC45929.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  iota
# 196  UKC45984.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  iota
# 197  UKC45996.1  YYPDK YPDKV PDKVF DKVFR KVFRS VFRSS FRSSV RSSV...  iota
# 198  UKC46300.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  iota
# 199  UKC46312.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  iota
#
# [200 rows x 3 columns]

# %%
df_kappa = pd.read_csv("./Datasets/KappaSP_Fragmented.csv")
df_kappa = df_kappa.iloc[:,1:] 
df_kappa.columns = ["ACC","Seq"]
df_kappa["Var"]="kappa" 
df_kappa
# Out:
#             ACC                                                Seq    Var
# 0    UNP61972.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# 1    UMP23874.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# 2    UMP40141.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# 3    UML30249.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# 4    UML30261.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# ..          ...                                                ...    ...
# 195  QVO76716.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# 196  QVO77206.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# 197  QVO78866.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# 198  QVP19118.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
# 199  QVQ47015.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  kappa
#
# [200 rows x 3 columns]

# %%
df_lam = pd.read_csv("./Datasets/LambdaSP_Fragmented.csv")
df_lam = df_lam.iloc[:,1:] 
df_lam.columns = ["ACC","Seq"]
df_lam["Var"]="lambda" 
df_lam
# Out:
#             ACC                                                Seq     Var
# 0    UQC43985.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  lambda
# 1    UQE64390.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  lambda
# 2    UPI04200.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  lambda
# 3    UPI04269.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  lambda
# 4    UPI05857.1  KVFRS VFRSS FRSSV RSSVL SSVLH SVLHS VLHST LHST...  lambda
# ..          ...                                                ...     ...
# 195  UDW43218.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  lambda
# 196  UDY39051.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  lambda
# 197  UDY39171.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  lambda
# 198  UDY39378.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  lambda
# 199  UDY43351.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  lambda
#
# [200 rows x 3 columns]

# %%
df_mu = pd.read_csv("./Datasets/MuSP_Fragmented.csv")
df_mu = df_mu.iloc[:,1:] 
df_mu.columns = ["ACC","Seq"]
df_mu["Var"]="mu" 
df_mu
# Out:
#             ACC                                                Seq Var
# 0    UQG79034.1  MFVFF FVFFV VFFVL FFVLL FVLLP VLLPL LLPLV LPLV...  mu
# 1    UQG80391.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
# 2    UQG80650.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
# 3    UQG81935.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
# 4    UQG84643.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
# ..          ...                                                ...  ..
# 195  UIX44783.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
# 196  UIX44794.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
# 197  UIT13030.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
# 198  UIT74528.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
# 199  UIT90716.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  mu
#
# [200 rows x 3 columns]

# %%
df_omi = pd.read_csv("./Datasets/OmicronSP_Fragmented.csv")
df_omi = df_omi.iloc[:,1:] 
df_omi.columns = ["ACC","Seq"]
df_omi["Var"]="omicron" 
df_omi
# Out:
#             ACC                                                Seq      Var
# 0    UQH67538.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# 1    UQH69591.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# 2    UQH70401.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# 3    UQH70628.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# 4    UQH70736.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# ..          ...                                                ...      ...
# 195  UQH22954.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# 196  UQH23074.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# 197  UQH23122.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# 198  UQH23157.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
# 199  UQH23181.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  omicron
#
# [200 rows x 3 columns]

# %%
df_ep1 = pd.read_csv("./Datasets/Epsilon_1SP_Fragmented.csv")
df_ep1 = df_ep1.iloc[:,1:] 
df_ep1.columns = ["ACC","Seq"]
df_ep1["Var"]="epsilon" 
df_ep1
# Out:
#             ACC                                                Seq      Var
# 0    UPW87690.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 1    UPW89624.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 2    UPW89648.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 3    UPM28220.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 4    UPM28554.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# ..          ...                                                ...      ...
# 195  UOT49396.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 196  UOT49408.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 197  UOT49420.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 198  UOT49432.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 199  UOT49468.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
#
# [200 rows x 3 columns]

# %%
df_ep2 = pd.read_csv("./Datasets/Epsilon_2SP_Fragmented.csv")
df_ep2 = df_ep2.iloc[:,1:] 
df_ep2.columns = ["ACC","Seq"]
df_ep2["Var"]="epsilon" 
df_ep2
# Out:
#             ACC                                                Seq      Var
# 0    UQG74971.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 1    UQE68448.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 2    UQE68543.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 3    UQE68918.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 4    UPW87678.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# ..          ...                                                ...      ...
# 195  UPM59614.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 196  UPM59638.1  IQCVN QCVNL CVNLT VNLTT NLTTR LTTRT TTRTQ TRTQ...  epsilon
# 197  UPM59650.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 198  UPM59674.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
# 199  UPM59698.1  MFVFL FVFLV VFLVL FLVLL LVLLP VLLPL LLPLV LPLV...  epsilon
#
# [200 rows x 3 columns]

# %%
df_var=[df_alpha,df_beta,df_gamma,df_delta,df_kappa,df_eta,df_iota,df_lam,df_ep1,df_ep2,df_mu,df_omi]
data=pd.concat(df_var,ignore_index=True)
data=data.iloc[:,1:]
data.to_csv("./Datasets/SpikeProteinFragmented.csv")
